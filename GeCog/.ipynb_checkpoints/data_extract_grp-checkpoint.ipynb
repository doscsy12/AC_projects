# %% [markdown]
# ## GeCog data analysis

# %% [markdown]
# *import libraries*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
# %matplotlib inline
import datetime 
import os
import glob
from scipy import interpolate
import statistics
import chime
# %load_ext chime

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.options.display.max_rows = 50

# %% [markdown]
# ### Data

# %%
patient_nr = 'P12'
path = './data/' + patient_nr

# %% [markdown]
# **H-MAN sensor data (FILE_ID.dat)**

# %%
# loop dfs from *.dat for defined patient_nr
list_of_dfs = []

list_of_dfs = [pd.read_csv(filename, sep='\t+', header=[1]) for filename in glob.glob(path + '/*.dat')]

# %%
# sample of one df
list_of_dfs[0]
# Out:
#         Time_msec  RawDataX  RawDataY  RawDataTorqueLeft  RawDataTorqueRight
# 0               0  0.170601  0.059062                  0                   0
# 1               5  0.170601  0.059062                  0                   0
# 2              10  0.170601  0.059062                  0                   0
# 3              15  0.170601  0.059062                  0                   0
# 4              20  0.170601  0.059062                  0                   0
# ...           ...       ...       ...                ...                 ...
# 565219    2814785  0.263215  0.213402                  0                   0
# 565220    2814790  0.263115  0.213452                  0                   0
# 565221    2814795  0.263039  0.213477                  0                   0
# 565222    2814800  0.262964  0.213553                  0                   0
# 565223    2814805  0.262863  0.213603                  0                   0
#
# [565224 rows x 5 columns]

# %%
# change column names to lowercase
for df in list_of_dfs:
    df.columns = df.columns.str.lower()

# %% [markdown]
# **Time-stamped data (FILE_ID.tsd)**

# %%
# loop tsds from *.tsd for each patient
list_of_tsds = []

list_of_tsds = [pd.read_csv(filename, sep='\t+', header=[1]) for filename in glob.glob(path + '/*.tsd')]

# %%
list_of_tsds[0]
# Out:
#         t            event_type      Obstacles/Outcome
# 0       289  service_event_start                     0
# 1       639            retrieval                     0
# 2       639            collision                     1
# 3       680            collision                     1
# 4       712         outcome_type                     1
# ..      ...                  ...                   ...
# 591  279874            retrieval                     0
# 592  280716            collision                     1
# 593  281218         outcome_type                     1
# 594  281721    service_event_end                     1
# 595  282224  service_event_start                     0
#
# [596 rows x 3 columns]

# %%
# standardize columns names
for tsd in list_of_tsds:
    tsd.columns = tsd.columns.str.replace(' ','')
    tsd.columns = tsd.columns.str.replace('/','_')
    tsd.columns = tsd.columns.str.lower()

# %% [markdown]
# **Game parameters (FILE_ID.par)**

# %%
list_of_pars = []

list_of_pars = [pd.read_csv(filename, header=[1]) for filename in glob.glob(path + '/*.par')]

# %%
# converting to one column 
list_of_pars[0]
# Out:
#                 CustomerCount:  12
# 0              SessionTimeout:  60
# 1                 FadeOutTime:  15
# 2          CustomerArrivalTime:  4
# 3                  TotalBlocks:  7
# 4               CognitiveLevel:  2
# 5                 HapticsLevel:  2
# 6    Damping Matrix A: 100 200 0 0
# 7        Damping Matrix B: 0 0 0 0
# 8  Damping Matrix C: -30 -30 20 20

# %% [markdown]
# **Researcher reports (FILE_ID.rep)**

# %%
list_of_reps = []

list_of_reps = [pd.read_csv(filename, header=[1]) for filename in glob.glob(path + '/*.rep')]

# %%
list_of_reps[0]
# Out:
#                    Patient ID:  p12_assess
# 0   SessionTerminationCondition  Completed
# 1                   SessionDuration  19.36
# 2                   sumofOutcomesType1  82
# 3                    sumofOutcomesType2  2
# 4                   sumofOutcomesType3  10
# 5                 TotalCustomersServed  84
# 6            AverageReactionTime  10.13103
# 7                         AverageSpeed   0
# 8                        CollisionRate   2
# 9       CumulativePointScoreCognitive  332
# 10           CumulativePointScoreMotor  80

# %% [markdown]
# **quality timestamp check**

# %%
for index in range(0,len(list_of_tsds)):
    diff = abs(list_of_tsds[index]['t'].iloc[-1]  - list_of_dfs[index]['time_msec'].iloc[-1]) 
    if diff > 15:
        print(f'trial{index},{diff} msec, TIME DISCREPANCY IN DATA')
    else:
        print(f'trial{index} pass')
# Out:
# trial0,2532581 msec, TIME DISCREPANCY IN DATA
# trial1 pass
# trial2 pass
# trial3 pass
# trial4 pass
# trial5 pass
# trial6 pass
# trial7 pass
# trial8 pass
# trial9 pass

# %% [markdown]
# ### EDA

# %% [markdown]
# #### wrt svc_event

# %% [markdown]
# ##### interpolate sensor data

# %% [markdown]
# **merge main**

# %%
list_of_mains = []

for tsd, df in zip(list_of_tsds,list_of_dfs):
    # check duplicates
    ids = df['time_msec']
    df[ids.isin(ids[ids.duplicated()])]
    
    # drop duplicates
    df = df.drop_duplicates(subset=['time_msec'],keep='first')
    
    df = df.set_index('time_msec')
    df = df.reindex(range(0,df.index.astype(int)[-1]+1), fill_value=np.nan)
    df = df.reset_index()
    df.drop(labels=0,axis=0,inplace=True)
    
    # interpolate missing data
    df['rawdatax'] = df['rawdatax'].interpolate().values.ravel().tolist()
    df['rawdatay'] = df['rawdatay'].interpolate().values.ravel().tolist()
    
    # merge main df
    main = pd.merge(tsd, df, how='left', left_on='t', right_on='time_msec')

    # index service_event start/end in main
    nr = 0
    main['sequence'] = 0
    for index, event in enumerate(main['event_type']):
        if event == 'service_event_end':
            main['sequence'].iloc[index] = nr
            nr += 1   
        else:
            main['sequence'].iloc[index] = nr
        
    list_of_mains.append(main)

# %%
list_of_mains[1]
# Out:
#            t           event_type  obstacles_outcome  time_msec  rawdatax  \
# 0         45  service_event_start                  0       45.0  0.168867
# 1       8430            retrieval                  0     8430.0  0.142578
# 2      10715         outcome_type                  1    10715.0  0.074694
# 3      10715    service_event_end                  1    10715.0  0.074694
# 4      10715  service_event_start                  0    10715.0  0.074694
# ..       ...                  ...                ...        ...       ...
# 629  1350800  service_event_start                  0  1350800.0  0.139352
# 630  1353995            retrieval                  0  1353995.0  0.288851
# 631  1355310         outcome_type                  1        NaN       NaN
# 632  1355315    service_event_end                  1        NaN       NaN
# 633  1355315  service_event_start                  0        NaN       NaN
#
#      rawdatay  rawdatatorqueleft  rawdatatorqueright  sequence
# 0    0.205762                0.0                 0.0         0
# 1    0.169219                NaN                 NaN         0
# 2    0.218052                0.0                 0.0         0
# 3    0.218052                0.0                 0.0         0
# 4    0.218052                0.0                 0.0         1
# ..        ...                ...                 ...       ...
# 629  0.217998                NaN                 NaN       146
# 630  0.169370                0.0                 0.0       146
# 631       NaN                NaN                 NaN       146
# 632       NaN                NaN                 NaN       146
# 633       NaN                NaN                 NaN       147
#
# [634 rows x 9 columns]

# %%
## double check NaN beginning and end of df

# %% [markdown]
# ##### mean speed

# %%
# mean speed
list_svc = []
mean_speed = []
max_speed = []
list_of_tot_svc = []

for idx, main in enumerate(list_of_mains):
    svc_event = main[main['event_type'].str.contains('service_event')]

    # group events based on svc_events
    svc_event[['time_diff','x_diff','y_diff']]=svc_event.groupby('sequence')[['time_msec','rawdatax','rawdatay']].diff()
    svc_event['step_size'] = np.sqrt(svc_event['x_diff']**2+svc_event['y_diff']**2)
    svc_event['speed'] = (svc_event['step_size'])/(svc_event['time_diff']/1000)
    svc_event.drop(columns=['rawdatatorqueleft','rawdatatorqueright'],inplace=True)
    svc_event = svc_event.dropna()
    list_svc.append(svc_event)
    
    # total number of customers served
    list_of_tot_svc.append(int(list_svc[idx]['sequence'].count()))

    mean_speed.append(statistics.mean(svc_event['speed']))
    max_speed.append(max(svc_event['speed']))

# %%
## quality check 
# no end for the last service_event_
list_of_tsds[0][list_of_tsds[0]['event_type'].str.contains('service')].tail(5)
# Out:
#           t           event_type  obstacles_outcome
# 579  276198  service_event_start                  0
# 586  278358    service_event_end                  1
# 587  278560  service_event_start                  0
# 594  281721    service_event_end                  1
# 595  282224  service_event_start                  0

# %%
# result mean_speed of all trials
mean_speed
# Out:
# [0.010084993232424984,
#  0.01627325239561165,
#  0.01119446779826725,
#  0.011022403285336031,
#  0.013170289266475859,
#  0.01489688186148147,
#  0.017274835726848143,
#  0.018475100733308016,
#  0.01813766679195982,
#  0.01634152548311976]

# %%
# plot speed and mean_speed based on svc_event
for index, svc_event in enumerate(list_svc):
    fig, ax = plt.subplots()

    ax.plot('sequence','speed',data=svc_event);
    ax.axhline(y=mean_speed[index], color='r', linestyle='-')
    
    plt.legend(['speed','mean_speed'])
    plt.xlabel('service event')
    plt.ylabel('speed/ m/msec')
    plt.ylim([0,0.040])
    plt.title('speed during play');

# %% [markdown]
# ##### ratio mean speed/max speed
# This ratio outlines the presence of a movement characterized by brisk movements and stops

# %%
# result max_speed of all trials
max_speed
# Out:
# [0.04048153497352858,
#  0.24721592135956574,
#  0.09544802081563492,
#  0.038161187160360835,
#  0.07151696873196664,
#  0.14569260039638532,
#  0.14765182889667358,
#  0.2418987926092053,
#  0.247448936558329,
#  0.21151414484869632]

# %%
stop_speed = [x/y for x,y in zip(mean_speed,max_speed)]

# %%
# result stop_speed of all trials
stop_speed
# Out:
# [0.24912576163477243,
#  0.06582606939762124,
#  0.11728339364825818,
#  0.28883806048846744,
#  0.1841561450379119,
#  0.10224871970814975,
#  0.116997099568181,
#  0.07637533256792683,
#  0.07329862493745001,
#  0.07725972886971431]

# %% [markdown]
# ##### service event errors rate

# %% [markdown]
#  1 (Correct item & correct person in sequence)
#  <br> 2 (Correct item & wrong person in sequence)
#  <br> 3 (Wrong item & wrong person in sequence).

# %%
# error rate
error_rate = []

for index, (main, svc_event) in enumerate(zip(list_of_mains,list_svc)):
    svc_error = main[main['event_type']=='service_event_end']['obstacles_outcome'].unique()
    
#     svc_event.reset_index(inplace=True)
    total_svc = int(svc_event['sequence'].tail(1))
    if 2 in svc_error:
        svc_error_2 = svc_event[svc_event['obstacles_outcome']==2]['obstacles_outcome'].count()
    else:
        svc_error_2 = 0
    if 3 in svc_error:
        svc_error_3 = svc_event[svc_event['obstacles_outcome']==3]['obstacles_outcome'].count()
    else:
        svc_error_3 = 0
        
    error_rate.append((svc_error_2 + svc_error_3)/list_of_tot_svc[index])

# %%
# result error_rate based on svc_event
error_rate
# Out:
# [0.1276595744680851,
#  0.0273972602739726,
#  0.10884353741496598,
#  0.027972027972027972,
#  0.034482758620689655,
#  0.06756756756756757,
#  0.04054054054054054,
#  0.05333333333333334,
#  0.0728476821192053,
#  0.05442176870748299]

# %% [markdown]
# ##### collision rate

# %% [markdown]
# collisions=1 if shelf
# <br> collisions=2 if object

# %%
# collision rate
collision_rate = []

for index, main in enumerate(list_of_mains):
    coll_1 = main[(main['event_type']=='collision') & (main['obstacles_outcome']==1)]['obstacles_outcome'].count()
    coll_2 = main[(main['event_type']=='collision') & (main['obstacles_outcome']==2)]['obstacles_outcome'].count()
    collision_rate.append((coll_1 + coll_2)/list_of_tot_svc[index])

# %%
collision_rate
# Out:
# [2.393617021276596,
#  0.3150684931506849,
#  1.7891156462585034,
#  0.8181818181818182,
#  0.6344827586206897,
#  0.527027027027027,
#  0.41216216216216217,
#  0.4066666666666667,
#  0.26490066225165565,
#  0.25170068027210885]

# %% [markdown]
# #### rolling

# %% [markdown]
# ##### mean speed (rolling)

# %% [markdown]
# ###### define window of interest

# %%
# this applies to all parameters
# %chime 
window = int(input("window: "))
# window = 7
# Out:
# window: 7

# %%
list_speed_roll = []

for index, svc_event in enumerate(list_svc):
    svc_event.set_index('sequence')
    svc_event['speed_roll']=svc_event['speed'].rolling(window).mean()
    list_speed_roll.append(svc_event['speed_roll'])
    
    #plot moving average based on window
    fig, ax = plt.subplots()
    ax.plot('sequence','speed_roll',data=svc_event);
    plt.xlabel('svc_event')
    plt.ylabel('speed/ m/msec')
    plt.title(f'moving average ({window} svc events) of speed during play');

# %% [markdown]
# ##### svc event errors rate (rolling)

# %%
list_error_rate = []

for index, svc_event in enumerate(list_svc):
    svc_event['error_rate'] = np.nan
    
    for i in range(0,(len(svc_event)-window+1)):
        svc_error = svc_event[svc_event['event_type']=='service_event_end']['obstacles_outcome'][i:i+window].unique()
        if 2 in svc_error:
            svc_error_2 = svc_event[i:i+window][svc_event['obstacles_outcome']==2]['obstacles_outcome'].count()
        else:
            svc_error_2 = 0
        if 3 in svc_error:
            svc_error_3 = svc_event[i:i+window][svc_event['obstacles_outcome']==3]['obstacles_outcome'].count()
        else:
            svc_error_3 = 0
        svc_event['error_rate'][i+window] = (svc_error_2 + svc_error_3)/window
        list_error_rate.append((svc_error_2 + svc_error_3)/window)
    
    #plot moving average based on window
    fig, ax = plt.subplots()
    ax.plot('error_rate',data=svc_event);
    plt.xlabel('service event')
    plt.ylabel('error rate')
    plt.title(f'moving average ({window} svc events) of error rate during play');

# %% [markdown]
# ##### total collision (svc, rolling)

# %%
list_tot_coll = []

for main in list_of_mains:
    collision = main[main['event_type'].str.contains('collision|service')]

    # collision 1
    coll_1 = collision[(collision['event_type']=='collision') & (collision['obstacles_outcome']==1)].groupby('sequence').count()[['obstacles_outcome']]
    coll_1 = coll_1.rename(columns={'obstacles_outcome':'coll_1'})

    # collision 2
    coll_2 = collision[(collision['event_type']=='collision') & (collision['obstacles_outcome']==2)].groupby('sequence').count()[['obstacles_outcome']]
    coll_2 = coll_2.rename(columns={'obstacles_outcome':'coll_2'})

    # total collisions
    total_coll = pd.merge(coll_1, coll_2, how='left', on='sequence').replace(np.nan,0)
    total_coll = total_coll.reindex(range(0,total_coll.index.astype(int)[-1]+1), fill_value=0)
    total_coll['total_coll'] = total_coll['coll_1'] + total_coll['coll_2']
    
    # mean total obstacles
    mean_total_obstacles = statistics.mean(total_coll['total_coll'])
    
    #
    fig, ax1 = plt.subplots()
    ax1.plot('total_coll',data=total_coll);
    ax1.axhline(y=mean_total_obstacles, color='r', linestyle='-')
    plt.legend(['total collision','mean collision'])
    plt.xlabel('service event')
    plt.ylabel('total collision')
    plt.title('total collision during play'); 
    
    # total collision (rolling)
    total_coll['total_coll7']=total_coll['total_coll'].rolling(window).mean()
    list_tot_coll.append(total_coll['total_coll'])
    
    #plot moving average based on window
    fig, ax2 = plt.subplots()
    ax2.plot('total_coll7',data=total_coll);
    plt.xlabel('service event')
    plt.ylabel('collision rate')
    plt.title(f'moving average ({window} svc events) of total collision during play');

# %% [markdown]
# ### export data to csv

# %%
for nr in range(1,len(list_of_mains)+1):
    list_of_mains[nr-1].to_csv('./data/' + patient_nr + '/main{nr}.csv'.format(nr=nr))
    list_svc[nr-1].to_csv('./data/' + patient_nr + '/speed{nr}.csv'.format(nr=nr))
    list_tot_coll[nr-1].to_csv('./data/' + patient_nr + '/collision{nr}.csv'.format(nr=nr))

# %%
# result
# mean_speed
# error_rate
# collision_rate
# mean_speed(rolling)
# error_rate(rolling)
# collision_rate(rolling)

# with open('result_' + patient_nr + '.csv', mode='a') as file_:
#     file_.write("{},{},{}".format(mean_speed, error_rate, collision_rate))
#     file_.write("\n")  # Next line.

# %%
import csv
with open('result_' + patient_nr + '.csv', mode='w') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(zip(mean_speed, max_speed, stop_speed, error_rate, collision_rate))

# %% [markdown]
# ### plot summary of ALL trials

# %%
results_path = os.path.join('data', 'results', patient_nr)
if not os.path.exists(results_path):
    os.makedirs(results_path)

# %%
progress = pd.DataFrame({'mean_speed': mean_speed, 
                         'max_speed': max_speed,
                         'stop_speed': stop_speed,
                        'error_rate': error_rate, 
                        'collision_rate': collision_rate})

# %%
progress
# Out:
#    mean_speed  max_speed  stop_speed  error_rate  collision_rate
# 0    0.010085   0.040482    0.249126    0.127660        2.393617
# 1    0.016273   0.247216    0.065826    0.027397        0.315068
# 2    0.011194   0.095448    0.117283    0.108844        1.789116
# 3    0.011022   0.038161    0.288838    0.027972        0.818182
# 4    0.013170   0.071517    0.184156    0.034483        0.634483
# 5    0.014897   0.145693    0.102249    0.067568        0.527027
# 6    0.017275   0.147652    0.116997    0.040541        0.412162
# 7    0.018475   0.241899    0.076375    0.053333        0.406667
# 8    0.018138   0.247449    0.073299    0.072848        0.264901
# 9    0.016342   0.211514    0.077260    0.054422        0.251701

# %%
progress.to_csv('./results/' + patient_nr + '_result.csv')

# %%
# plot mean_speed of all trials
plt.bar(progress.index,height=progress['mean_speed']);
plt.xlabel('trial')
plt.ylabel('mean speed');
plt.title('mean speed by trial');

# %%
# plot error_rate of all trials
plt.bar(progress.index,height=progress['error_rate']);
plt.xlabel('trial')
plt.ylabel('error rate');
plt.title('service error rate by trial');

# %%
# plot collisions of all trials
plt.bar(progress.index,height=progress['collision_rate']);
plt.xlabel('trial')
plt.ylabel('collision rate');
plt.title('collision rate by trial');

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        pass
    
if patient_nr == 'P11':
    chime.error()
    print('P11 has no assess_2 trial')
    raise StopExecution

# %% [markdown]
# ### plot summary of intervention trials only (not assess)

# %%
interventn = progress.iloc[2:].reset_index().drop(columns=['index'])
interventn.index = np.arange(1, len(interventn)+1)
interventn
# Out:
#    mean_speed  max_speed  stop_speed  error_rate  collision_rate
# 1    0.011194   0.095448    0.117283    0.108844        1.789116
# 2    0.011022   0.038161    0.288838    0.027972        0.818182
# 3    0.013170   0.071517    0.184156    0.034483        0.634483
# 4    0.014897   0.145693    0.102249    0.067568        0.527027
# 5    0.017275   0.147652    0.116997    0.040541        0.412162
# 6    0.018475   0.241899    0.076375    0.053333        0.406667
# 7    0.018138   0.247449    0.073299    0.072848        0.264901
# 8    0.016342   0.211514    0.077260    0.054422        0.251701

# %%
interventn = progress.iloc[2:].reset_index().drop(columns=['index'])
interventn.index = np.arange(1, len(interventn)+1)
plt.bar(interventn.index,height=interventn['mean_speed']);
plt.xlabel('trial')
plt.ylabel('mean speed/ m/msec');
plt.ylim([0, 0.02])
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.title('mean speed by trial');
plt.savefig(results_path + '\interventn_mean_speed.png',bbox_inches = "tight")
plt.show()

# %%
interventn = progress.iloc[2:].reset_index().drop(columns=['index'])
interventn.index = np.arange(1, len(interventn)+1)
plt.bar(interventn.index,height=interventn['error_rate']);
plt.xlabel('trial')
# labels = ['1','2','3','4']
# plt.xticks(temp.index, labels)
plt.ylabel('error rate');
plt.ylim([0, 0.3])
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.title('service error rate by trial');
plt.savefig(results_path + '\interventn_error_rate.png')
plt.show()

# %%
interventn = progress.iloc[2:].reset_index().drop(columns=['index'])
interventn.index = np.arange(1, len(interventn)+1)
plt.bar(interventn.index,height=interventn['collision_rate']);
plt.xlabel('trial')
plt.ylabel('collision rate');
plt.ylim([0, 2.5])
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.title('collision rate by trial');
plt.savefig(results_path + '\interventn_collision_rate.png')
plt.show()

# %% [markdown]
# ### plot summary of assessment trials only

# %%
assess = progress.iloc[0:2].reset_index().drop(columns=['index'])
assess.index = np.arange(1, len(assess)+1)
assess
# Out:
#    mean_speed  max_speed  stop_speed  error_rate  collision_rate
# 1    0.010085   0.040482    0.249126    0.127660        2.393617
# 2    0.016273   0.247216    0.065826    0.027397        0.315068

# %%
assess = progress.iloc[0:2].reset_index().drop(columns=['index'])
assess.index = np.arange(1, len(assess)+1)
plt.bar(assess.index,height=assess['mean_speed']);
plt.xlabel('trial')
plt.ylabel('mean speed/ m/msec');
plt.ylim([0, 0.02])
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.title('mean speed by trial');
plt.savefig(results_path + '\\assess_mean_speed.png',bbox_inches = "tight")
plt.show()

# %%
assess = progress.iloc[0:2].reset_index().drop(columns=['index'])
assess.index = np.arange(1, len(assess)+1)
plt.bar(assess.index,height=assess['error_rate']);
plt.xlabel('trial')
# labels = ['1','2','3','4']
# plt.xticks(temp.index, labels)
plt.ylabel('error rate');
plt.ylim([0, 0.3])
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.title('service error rate by trial');
plt.savefig(results_path + '\\assess_error_rate.png')
plt.show()

# %%
assess = progress.iloc[0:2].reset_index().drop(columns=['index'])
assess.index = np.arange(1, len(assess)+1)
plt.bar(assess.index,height=assess['collision_rate']);
plt.xlabel('trial')
plt.ylabel('collision rate');
plt.ylim([0, 2.5])
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
plt.title('collision rate by trial');
plt.savefig(results_path + '\\assess_collision_rate.png')
plt.show()

# %%
# %chime
